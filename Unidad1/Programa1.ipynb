# %% [markdown]
# <a href="https://colab.research.google.com/github/XoloitzcuintleChicloso/FundamentosProgramacion/blob/main/Unidad1/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
X = 5
X = "hola mundo uwu"
X = True
print("El valor de x es", X)
# Out:
# El valor de x es True

# %%
base = int(input("Dame la base del triangulo"))
altura = int(input("Dame la altura del triangulo"))
area = (base * altura)/2
print("El area del triangulo =",area)

# %%
variable1 = 50
variable2 = 50
if variable1 > variable2:
  print(variable1, "es mayor que", variable2)
else:
  print(variable1, "es menor que", variable2)
# Out:
# 50 es menor que 50
