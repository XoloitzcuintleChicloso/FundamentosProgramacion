# %% [markdown]
# <a href="https://colab.research.google.com/github/XoloitzcuintleChicloso/FundamentosProgramacion/blob/main/Unidad1/Sistema_de_prestamos_version_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ingenieria en Sistemas Computacionales**
# ## **Fundamentos de Programación**
# ## **Unidad 1**
# *Sistemas de gestion de prestamos y reservaciones de computadoras - version 1*
# Docente: ***Jose Gabriel Rivas Rodriguez***
# Alumno(a): ***Ricardo Sariñana Ochoa***
# Grupo 1YY
# Primer Semestre

# %%
X = 5
X = "hola mundo uwu"
X = True
print("El valor de x es", X)
# Out:
# El valor de x es True

# %%
base = int(input("Dame la base del triangulo"))
altura = int(input("Dame la altura del triangulo"))
area = (base * altura)/2
print("El area del triangulo =",area)

# %%
variable1 = 50
variable2 = 50
if variable1 > variable2:
  print(variable1, "es mayor que", variable2)
elif variable1 == variable2:
  print(variable1, "es igual que", variable2)
else:
  print(variable1, "es menor que", variable2)
# Out:
# 50 es igual que 50

# %%
    edad = int(input("dame tu edad"))
    if edad <= 10:
      print("Eres un niño")
    elif edad <= 18:
      print("Eres un adolescente")
    elif edad <= 30:
      print("Eres un joven adulto")
    elif edad <= 65:
      print("Eres un adulto")
    else:
      print("Eres un adulto mayor")
# Out:
# dame tu edad25
# Eres un joven adulto

# %%
    edad = int(input("dame tu edad"))

    if edad <= 65 and edad > 30:
      print("Eres un adulto")
    elif edad <= 30 and edad > 18:
      print("Eres un joven adulto")
    elif edad <= 18 and edad > 10:
      print("Eres un adolescente")
    elif edad <= 10 and edad > 0:
      print("Eres un niño")
    else:
      print("Eres un adulto mayor")
# Out:
# dame tu edad0123456789
# Eres un adulto mayor

# %%
5 > 10 #esto es un valor booleano que se regresa verdadero o falso dependiendo si se cumple o no
# Out:
# False

# %%
10 > 5
# Out:
# True

# %%
10 > 5 and 10 > 7 and 10 > 1
# Out:
# True

# %%
10 > 5 and 10 > 7 and 10 > 11
# Out:
# False

# %%
10 > 5 or 10 > 7 or 10 > 11
# Out:
# True

# %%
# instruccion for sirve para repetir instrucciones
tabla = 16
for i in range(16, 200, 16):
  print(tabla, "*", i, "=", tabla*i)
# Out:
# 16 * 16 = 256
# 16 * 32 = 512
# 16 * 48 = 768
# 16 * 64 = 1024
# 16 * 80 = 1280
# 16 * 96 = 1536
# 16 * 112 = 1792
# 16 * 128 = 2048
# 16 * 144 = 2304
# 16 * 160 = 2560
# 16 * 176 = 2816
# 16 * 192 = 3072

# %% [markdown]
# **Listas en phyton**

# %%
alumnos = ["ana", "luis", "carlos"]
print(alumnos)
# Out:
# ['ana', 'luis', 'carlos']

# %%
alumnos [1] = "juan"

print(alumnos)
print(alumnos[-1])

alumnos.append("sandra")

print(alumnos)

#cuando quieres eliminar un valor puedes usar remove() o pop(), tambien del es una forma de eliminar
# Out:
# ['ana', 'juan', 'carlos', 'sandra', 'sandra', 'sandra', 'sandra']
# sandra
# ['ana', 'juan', 'carlos', 'sandra', 'sandra', 'sandra', 'sandra', 'sandra']

# %%
#remove borra un elemento de la lista, si existen valores repetidos borra el primer valor que encuentra.

print(alumnos)
alumnos.remove("sandra")
print(alumnos)
# Out:
# ['ana', 'juan', 'carlos', 'sandra', 'sandra', 'sandra', 'sandra', 'sandra']
# ['ana', 'juan', 'carlos', 'sandra', 'sandra', 'sandra', 'sandra']

# %%
print(alumnos)
alumnos.pop(5)
print(alumnos)
# Out:
# ['ana', 'juan', 'carlos', 'sandra', 'sandra', 'sandra']
# ['ana', 'juan', 'carlos', 'sandra', 'sandra']

# %%
#ciclo para recorrer la lista y hacer algun proceso
print(alumnos)
for x in alumnos:
  print(x)
if x == "sandra":
  print("encontramos a sandra")
break #break forza a salir de un ciclo
# Out:
# ['ana', 'juan', 'carlos', 'sandra', 'sandra', 'sandra', 'sandra', 'sandra', 'sandra', 'sandra']
# ana
# juan
# carlos
# sandra
# sandra
# sandra
# sandra
# sandra
# sandra
# sandra
# encontramos a sandra
#   File "/tmp/ipykernel_902/1713801143.py", line 7
#     break #break forza a salir de un ciclo
#     ^
# SyntaxError: 'break' outside loop

# %%
# 2. Buscar por software
elif opcion == 2:
  programa = input( "\nIngrese el software que desea buscar: ")
  print("\n--- RESULTADOS ---")
  encontrado = False
  for i in range(len(computadoras)):
    #la funcion (lower) convierte a minuscula el texto, de esta forma
    #nos aseguramos que el texto a buscar y la informacion de las listas
    #este en minuscula y no tengamos problema de que no encuentra un programa
    #porque este escrito de forma diferente usando mayusculas y minusculas.
    if programa.lower() in software[i].lower():
      print("ID:", computadoras[i])
      print("Aula:", aulas[i])
      print("Software:", software[i])
      print("Estado:", estados[i])
      encontrado = True

if encontrado == False:
  print("No se encontraron computadoras con este software")
# Out:
#   File "/tmp/ipykernel_1115/2929101939.py", line 2
#     elif opcion == 2:
#     ^
# SyntaxError: invalid syntax
